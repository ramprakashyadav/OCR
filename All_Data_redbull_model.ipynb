# %% [markdown]
# <a href="https://colab.research.google.com/github/ramprakashyadav/OCR/blob/main/All_Data_redbull_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pdfplumber
# Out:
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Requirement already satisfied: Wand>=0.6.7 in /usr/local/lib/python3.7/dist-packages (from pdfplumber) (0.6.7)
# Requirement already satisfied: Pillow>=8.4 in /usr/local/lib/python3.7/dist-packages (from pdfplumber) (9.1.0)
# Requirement already satisfied: pdfminer.six==20211012 in /usr/local/lib/python3.7/dist-packages (from pdfplumber) (20211012)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.7/dist-packages (from pdfminer.six==20211012->pdfplumber) (36.0.2)
# Requirement already satisfied: chardet in /usr/local/lib/python3.7/dist-packages (from pdfminer.six==20211012->pdfplumber) (3.0.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography->pdfminer.six==20211012->pdfplumber) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography->pdfminer.six==20211012->pdfplumber) (2.21)

# %%
import pdfplumber
import os

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/redbull_model/
# Out:
# /content/gdrive/My Drive/redbull_model

# %%
REDBULL_INPUT_FOLDER = "/content/gdrive/MyDrive/redbull_model/redbull_input_folder/"
FUJITSU_INPUT_FOLDER = "/content/gdrive/MyDrive/redbull_model/fujitsu_input_folder/"
OUTPUT_FOLDER = "/content/gdrive/MyDrive/redbull_model/output_text/"

# %%
for fl in os.listdir(INPUT_FOLDER):

  pdf = pdfplumber.open(INPUT_FOLDER+fl)
  pdf_text=pdf.pages[0].extract_text()
  with open(OUTPUT_FOLDER + fl.replace('.pdf','.txt'),'w') as f:
    f.write(pdf_text)

# %%
# !pip install -U spacy -q
# !python -m spacy info
# Out:
#      |████████████████████████████████| 6.0 MB 5.4 MB/s
#      |████████████████████████████████| 653 kB 54.2 MB/s
#      |████████████████████████████████| 42 kB 1.7 MB/s
#      |████████████████████████████████| 10.1 MB 43.4 MB/s
#      |████████████████████████████████| 451 kB 52.8 MB/s
#      |████████████████████████████████| 181 kB 62.1 MB/s
#
# ============================== Info about spaCy ==============================
#
# spaCy version    3.2.4
# Location         /usr/local/lib/python3.7/dist-packages/spacy
# Platform         Linux-5.4.144+-x86_64-with-Ubuntu-18.04-bionic
# Python version   3.7.13
# Pipelines

# %%
import spacy
from spacy.tokens import DocBin
from tqdm import tqdm

nlp = spacy.blank("en")
db = DocBin()

# %%
import json
f = open('training_data.json')
TRAIN_DATA = json.load(f)

# %%
for text, annot in tqdm(TRAIN_DATA['annotations']):
    doc = nlp.make_doc(text)
    ents = []
    for start, end, label in annot["entities"]:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
          print("Skipping entity")
        else:
          ents.append(span)
    doc.ents = ents
    db.add(doc)

db.to_disk("./training_data.spacy")
# Out:
# 100%|██████████| 885/885 [00:00<00:00, 2209.24it/s]

# %%
# !python -m spacy init config config.cfg --lang en --pipeline ner --optimize efficiency
# Out:
# ⚠ To generate a more effective transformer-based config (GPU-only),
# install the spacy-transformers package and re-run this command. The config
# generated now does not use transformers.
# ℹ Generated config template specific for your use case
# - Language: en
# - Pipeline: ner
# - Optimize for: efficiency
# - Hardware: CPU
# - Transformer: None
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy train config.cfg --output ./ --paths.train ./training_data.spacy --paths.dev ./training_data.spacy
# Out:
# ℹ Saving to output directory: .
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
GST: 11,628.35</br>Mfg. Dt.: 01.09.2021-5 CESS: 12</br>1,163.00</br>Batch No: 1957054</br>CESS: 997.00</br>IGST: 0.00</br>RB Red Edition IN Alu Can 24x250ml</br>CGST: 2,326.00</br>RB235674 GST: 28</br>20 22029990 10 BOX 1,661.07 16,610.70 0.00 16,610.70 SGST/UGST: 23,255.70</br>Mfg. Dt.: 26.10.2021-10 CESS: 12</br>2,326.00</br>Batch No: 1975317</br>CESS: 1,993.00</br>IGST: 0.00</br>Red Bull ED IN Alu Can 24x350ml</br>CGST: 1,466.00</br>RB201709 GST: 28</br>30 22029990 5 BOX 2,094.40 10,472.00 0.00 10,472.00 SGST/UGST: 14,661.00</br>Mfg. Dt.: 13.06.2021-4;28.04.2021-1 CESS: 12</br>1,466.00</br>Batch No: 1932313,1918841</br>CESS: 1,257.00</br>IGST: 0.00</br>Red Bull Energy Drink IN 250ml</br>CGST: 24,883.00</br>RB30925 GST: 28</br>40 22029990 107 BOX 1,661.07 177,734.49 0.00 177,734.49 SGST/UGST: 248,828.49</br>Mfg. Dt.: 20.09.2021-107 CESS: 12</br>24,883.00</br>Batch No: 1962068</br>CESS: 21,328.00</br>Total 213,122.54 0.00 213,122.54 85,251.00 298,373.54</br>TCS 298.38</br>Total Amount 298,671.92</br>Amount in words:INR Two Lakh Ninety Eight Thousand Six Hundred Seventy One and Ninety Two Paisa Only</br>Payment Terms - Due immediately</br>Declaration:</br>No credit of additional duty of custom (ADC) is admissible to the buyer. We declare that this document shows the actual price of the goods described and that all particular are true and</br>correct. </br>We hereby certify that food/foods mentioned in this document is / are warranted to be of the nature and quality which it/these purports/purport to be.</br>No. of Box: 127</br>Gross weight - 866.760</br>FSSAI Lic. No - 12721066000743</br>For Red Bull India Pvt. Ltd.</br>Authorised signatory</br>Red Bull India Pvt. Ltd.</br>Registered Office Address: 1st Floor, B Wing, 215 Atrium, Kanakia Spaces, Chakala, Andheri Kurla Road, Andheri (E) Mumbai-400093. www.redbull.in</br>Tel:+91-22-66180888, Fax:+91-22-66180808, Email: info.in@redbull.com, CIN:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U51909MH2007FTC169580
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CIN NO</span>
# </mark>
#  PAN:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AADCR5842H
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY PAN NO</span>
# </mark>
# </div></span>

# %%
import pandas as pd
import re

# %%
def extract_text_redbull_table(INPUT_FOLDER, output_csv):

  all_data =[]
  for fl in os.listdir(INPUT_FOLDER):
      print(fl)
      pdf_obj = pdfplumber.open(INPUT_FOLDER + fl)
      tot_pages = len(pdf_obj.pages)
      invoice_no =  ''
      invoice_date = ''
      ref_no = ''
      ref_date = ''
      place_supply = ''
      transporter = ''
      transporter_name = ''
      vehicle_no = ''
      lr_no = ''
      for page_num, page in enumerate(pdf_obj.pages):
          tables = page.extract_tables()
          page_txt = page.extract_text()
          # print(page_txt)
          if 'CREDIT NOTE' in page_txt:
            print("abccccccccffffffffff",fl)
          if page_num == 0:
#             print(page_text)
            page_text_new = page_txt
            for text_row in tables[0][1][0].split('\n'):
#                 print(">>>>>>>", text_row )
                page_text_new = page_text_new.replace(text_row, '')
            # print(page_text_new)
    
            bill_from = re.search(r'Bill From(.*)Invoice To', page_text_new.replace('\n', ''))
            bill_from = bill_from[0].replace("Bill From", "").replace("Invoice To", '').replace("TAX INVOICE", "").replace("CREDIT NOTE", "")
            invoice_to = re.search(r'Invoice To(.*)Delivery Address', page_text_new.replace('\n', ''))
            invoice_to = invoice_to[0].replace("Invoice To", "").replace("Delivery Address", '')
            del_address = re.search(r'Delivery Address(.*)IRN', page_text_new.replace('\n', ''))
            del_address = del_address[0].replace("Delivery Address", "").replace("IRN", "")
            cin_ = re.search(r'CIN:(.*)PAN', page_text_new.replace('\n', ''))
            cin_ = cin_[0].replace("CIN:", "").replace("PAN", '')
            pan_ = re.search(r'PAN: (.*)', page_text_new)
            pan_ = pan_[0].replace("PAN: ", "")
        
          for table in tables:
              if (('INVOICE' in ''.join(table[0])) or ('CREDIT NOTE' in ''.join(table[0]))):
                  invoice_no =  table[1][0].split('\n')[0].replace('Invoice No:','').strip()
                  # print(invoice_no)
                  invoice_date = table[1][0].split('\n')[1].replace('Invoice Date:','').strip()
                  ref_no = table[1][0].split('\n')[2].replace('Ref. No.','').strip()
                  ref_date = table[1][0].split('\n')[3].replace('Ref Date:','').strip()
                  place_supply = table[1][0].split('\n')[4].replace('Place of Supply:','').strip()
                  transporter = table[1][0].split('\n')[5].replace('Transporter:','').strip()
                  transporter_name = table[1][0].split('\n')[6].replace('TransporterName:','').strip()
                  vehicle_no = table[1][0].split('\n')[7].replace('Vehicle No:','').strip()
                  lr_no = table[1][0].split('\n')[8].replace('LR no:','').strip()
                
              if 'Serial No' in ''.join(table[0]) or 'Item' in ''.join(table[0]):
                  table_df = pd.DataFrame(table[1::],columns=table[0])
                  # print(table_df.columns)
                  for idx, row in table_df.iterrows():
                      if row['Serial No']: #.isnumeric():
                          # print(type(row['Serial No']))
  #                         print(idx)
                          if idx == 0:
                              doc = nlp_ner(page_txt)
                              all_label_text = []
                              for ent in doc.ents:
                                # print(ent.label_)
                                if ent.label_ == "COMPANY NAME":
                                  company_name = ent.text
                                if ent.label_ == "INVOICE DATE":
                                  invoice_date = ent.text
                                if ent.label_ == "COMPANY GSTIN NUMBER":
                                  company_gstin = ent.text
                                if ent.label_ == "VEHICLE NO":
                                  vehicle_no = ent.text
                                if ent.label_ == "BUYER GSTIN NUMBER":
                                  buyer_gstin = ent.text
                                if ent.label_ == "CIN NO":
                                  cin_no = ent.text
                                if ent.label_ == "COMPANY PAN NO":
                                  company_pan = ent.text

                          tot_row = row['Serial No'] == 'Total'
                          if tot_row:

                            receipt_tot_amt = table_df[table_df['Serial No'] == 'Total Amount']['Total Amt. (INR)'].values[0]
                            # tcs =  table_df[table_df['Serial No'] == 'TCS']['Total Amt. (INR)'].values[0]
                            all_data.append([invoice_no,bill_from, invoice_to, del_address, cin_, pan_, invoice_date, ref_no, ref_date, place_supply, transporter, transporter_name, vehicle_no, lr_no,company_name,invoice_date,company_gstin,vehicle_no,buyer_gstin,cin_no,company_pan,receipt_tot_amt, row['Gross Amt.'], row['Discount Amt.'], row['Net Amt.'], row['GST Tax Amt.'], row['Total Amt. (INR)'], row['Serial No'], row['Material Description'], row['HSN/SAC'], row['Qty'], row['Rate Per\nItem'], row['Gross Amt.'], row['Discount Amt.'], row['Net Amt.'], row['GST Rate %'], row['GST Tax Amt.'],row['Total Amt. (INR)']])
                          else:
                              all_data.append([invoice_no,bill_from, invoice_to, del_address, cin_, pan_, invoice_date, ref_no, ref_date, place_supply, transporter, transporter_name, vehicle_no, lr_no,'','','','','','','','','','','','','', row['Serial No'], row['Material Description'], row['HSN/SAC'], row['Qty'], row['Rate Per\nItem'], row['Gross Amt.'], row['Discount Amt.'], row['Net Amt.'], row['GST Rate %'], row['GST Tax Amt.'], row['Total Amt. (INR)']  ])
                      
                  print("_________________________")
  out_df = pd.DataFrame(all_data, columns= ['Invoice No','Bill From', 'Invoice To', 'Delivery Address', 'CIN', 'PAN','Invoice Date', 'Ref No', 'Ref Date', 'Place of supply', 'Transporter', 'Transporter Name', 'Vehicle No', 'LR No', 'COMPANY NAME','INVOICE DATE','COMPANY GSTIN NUMBER','VEHICLE NO','BUYER GSTIN NUMBER','CIN NO','COMPANY PAN NO', 'Invoice Total Amt', 'Total Gross Amt.', 'Total Discount Amt.', 'Total Net Amt.', 'Total GST Tac Amt.','Total Total Amt. (INR) ','Serial No', 'Material Description', 'HSN/SAC', 'Qty', 'Rate Per\nItem',
       'Gross Amt.', 'Discount Amt.', 'Net Amt.', 'GST Rate %', 'GST Tax Amt.',
       'Total Amt. (INR)'])
  out_df = out_df[['Invoice No','Bill From', 'Invoice To', 'Delivery Address', 'CIN', 'PAN','Invoice Date', 'Ref No', 'Ref Date', 'Place of supply', 'Transporter', 'Transporter Name', 'Vehicle No', 'LR No', 'Invoice Total Amt', 'Total Gross Amt.', 'Total Discount Amt.', 'Total Net Amt.', 'Total GST Tac Amt.','Total Total Amt. (INR) ','Serial No', 'Material Description', 'HSN/SAC', 'Qty', 'Rate Per\nItem',
       'Gross Amt.', 'Discount Amt.', 'Net Amt.', 'GST Rate %', 'GST Tax Amt.',
       'Total Amt. (INR)']]
  out_df =out_df[~out_df['Serial No'].isin(['TCS', 'Total Amount'])]
  for inv_no in out_df['Invoice No'].unique():
    for col in ['Invoice Total Amt','Bill From', 'Invoice To', 'Delivery Address', 'CIN', 'PAN','Invoice Date', 'Ref No', 'Ref Date', 'Place of supply', 'Transporter', 'Transporter Name', 'Vehicle No', 'LR No',  'Total Gross Amt.', 'Total Discount Amt.', 'Total Net Amt.', 'Total GST Tac Amt.','Total Total Amt. (INR) ']:
        # print(col)
        out_df.loc[((out_df['Invoice No'] == inv_no)), col] = out_df[((out_df['Invoice No'] == inv_no) & (out_df['Serial No'] == 'Total'))][col].values[0]

  out_df =out_df[~(out_df['Serial No'] == "Total")]   
  out_df.to_csv(OUTPUT_FOLDER+ output_csv)

# %%
extract_text_redbull_table(REDBULL_INPUT_FOLDER,'102.csv')
# Out:
# GRANARYWHOLESALEPRIVATELIMITE_4203304843.pdf
# _________________________
# GRANARYWHOLESALEPRIVATELIMITE_4203304814.pdf
# _________________________
# GOYALTRADERS_4203304821.pdf
# _________________________
# AkribizBusinessSolutionsPvtLt_4203304889.pdf
# _________________________
# AkribizBusinessSolutionsPvtLt_4203304817.pdf
# _________________________
# _________________________
# GRANARYWHOLESALEPRIVATELIMITE_4203304784.pdf
# _________________________
# GRANARYWHOLESALEPRIVATELIMITE_4203304848.pdf
# _________________________
# GRANARYWHOLESALEPRIVATELIMITE_4203
pdf
# _________________________
# GRANARYWHOLESALEPRIVATELIMITE_4203304387.pdf
# _________________________
# GRANARYWHOLESALEPRIVATELIMITE_4203304372.pdf
# _________________________
# GRANARYWHOLESALEPVTLTD_4250010586.pdf
# _________________________
# GRANARYWHOLESALEPVTLTD_4250010587.pdf
# _________________________
# GRANARYWHOLESALEPRIVATELIMITE_4203304441.pdf
# _________________________
# GRANARYWHOLESALEPRIVATELIMITE_4203509177.pdf
# abccccccccffffffffff GRANARYWHOLESALEPRIVATELIMITE_4203509177.pdf
# _________________________
# GRANARYWHOLESALEPRIVATELIMITE_4203304386.pdf
# _________________________
# GRANARYWHOLESALEPVTLTD_4203304380.pdf
# _________________________
# GRANARYWHOLESALEPRIVATELIMITE_4203304349.pdf
# _________________________
# GRANARYWHOLESALEPVTLTD_4250010591.pdf
# _________________________
# RedBullIndiaPvt.Ltd_4203509177.pdf
# abccccccccffffffffff RedBullIndiaPvt.Ltd_4203509177.pdf
# _________________________
# RedBullIndiaPvt.Ltd_4203509320.pdf
# abccccccccffffffffff RedBullIndiaPvt.Ltd_4203509320.pdf
# _________________________
# GRANARYWHOLESALEPVTLTD_4250010589.pdf
# _________________________
# GRANARYWHOLESALEPVTLTD_4250010590.pdf
# _________________________
# GRANARYWHOLESALEPVTLTD_4250010588.pdf
# _________________________
# AkribizBusinessSolutionsPvtLt_4203304782 (1).pdf
# _________________________
# _________________________
# AkribizBusinessSolutionsPvtLt_4203304817 (1).pdf
# _________________________
# _________________________

# %%
def extract_text_fujitsu_table(INPUT_FOLDER, output_csv):
  all_data =[]
  for fl in os.listdir(INPUT_FOLDER):
      print(fl)
      pdf_obj = pdfplumber.open(INPUT_FOLDER + fl)
      tot_pages = len(pdf_obj.pages)
      for page_num, page in enumerate(pdf_obj.pages):
          tables = page.extract_tables()
  #         print(tables)
          invoice_no = ''
          invoice_date = ''
          for idx, row in pd.DataFrame(tables[0]).iterrows():
  #             print(row)
            
              if (('invoice' in ' '.join(row.fillna('').values).lower())  & ('date' in ' '.join(row.fillna('').values).lower())):
                  for spl in ' '.join(row.fillna('').values).split('\n'):
                    
                      if 'Invoice Number' in spl:
                          invoice_no = spl.replace('Invoice Number', '').replace(':', '').strip()
                      if 'Invoice Date' in spl:
                          invoice_date = spl.replace('Invoice Date', '').replace(':', '').strip()
                        
                    
              if (('ref' in ' '.join(row.fillna('').values).lower())  & ('date' in ' '.join(row.fillna('').values).lower())):
                  for spl in ' '.join(row.fillna('').values).split('\n'):
  #                     print(">>>>>>>",spl)
                      if 'Ref:' in spl:
                          invoice_no = spl.split('Ref:')[1].replace(':', '').strip()
                      if 'Date :' in spl:
                          invoice_date = spl.replace('Date :', '').replace(':', '').strip()
                    
            
              if (('item' in ' '.join(row.fillna('').values).lower()) & ('quantity' in ' '.join(row.fillna('').values).lower())):
                  hdr_idx = idx
            
                
            
                  df_ = pd.DataFrame(tables[0][hdr_idx+1::],columns=tables[0][hdr_idx])
        
                  tot_amt = ''
                    
                  amount = ''
                  quant = ''
                  unit_price = ''
                  hsn = ''
                  for idx, row in df_.fillna('').iterrows():

                      if 'Item\nNo' in df_.columns:
                          sl_no = row['Item\nNo']
                      if 'Sl.No.' in df_.columns:
                          sl_no = row['Sl.No.']
  #                     print(sl_no)
                      if sl_no.isnumeric():
                          sl_no_ = sl_no
                          if 'Quantity' in df_.columns:
                              quant = row['Quantity']
                          if 'Amount' in df_.columns:
                              amount = row['Amount']
                          if 'Unit Price' in df_.columns:
                              unit_price = row['Unit Price']
                          for col in df_.columns:
                              print(col, type(col))
                              if col != None:
  #                                 print('yo')
                  #                 continue
                                  if 'description' in col.lower():
                                      prod_desc = row[col]
                  #                     print(prod_desc)
                                      if 'unit\nprice' in col.lower():
                                          print('?????????',prod_desc)
                                          unit_price = prod_desc.split('\n')[0].split(' ')[-1]

                                      for splt_ in prod_desc.split('\n'):
  #                                         print(splt_)
                                          if 'HSN Code' in splt_:
                                              hsn = splt_.replace('HSN Code:','').strip()
                                          elif 'HSN' in splt_:
                                              hsn = splt_.replace('HSN:', '').strip()
                                          if 'VALUE IN INR :' in splt_:
  #                                             print('>>>>')
                                              tot_amt = splt_.replace('VALUE IN INR :', '').strip()

                      if row['Quantity'] == 'Total':
                          tot_amt = row['Amount']


                  all_data.append([invoice_no, invoice_date, tot_amt, sl_no_,prod_desc,hsn,unit_price, quant, amount])
  out_df = pd.DataFrame(all_data, columns = ['Invoice No', 'Invoice Date', 'Invoice Total Amount', 'Serial No', 'Material Description', 'HSN','Unit Price', 'Quantity', 'Amount'])
  out_df.to_csv(OUTPUT_FOLDER+ output_csv)

# %%
extract_text_fujitsu_table(FUJITSU_INPUT_FOLDER, '102.csv')
# Out:
# MH2720000523 (3).pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000522.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000521.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000515.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000516.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000472.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000514.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000473.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000475.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000519.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000520.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000518.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000517.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# PFU 1828-14.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Installation DVD's for SV600 5,000
# HSN: 8473 30 99
# VALUE IN INR : 10,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1828-8.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Installation DVD's for SV600 5,000
# HSN: 8473 30 99
# VALUE IN INR : 10,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1828-9.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description  Unit
# Price <class 'str'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1828-7.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Installation DVD's for SV600 5,000
# HSN: 8473 30 99
# VALUE IN INR : 10,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1828-6.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Installation DVD's for SV600 5,000
# HSN: 8473 30 99
# VALUE IN INR : 10,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1828-5.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Installation DVD's for SV600 5,000
# HSN: 8473 30 99
# VALUE IN INR : 10,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1828-4.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Installation DVD's for SV600 5,000
# HSN: 8473 30 99
# VALUE IN INR : 10,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# HR0620000143_Integra_Delhi.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000469.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000470.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# HR0620000143.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000471.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# HR0620000142_Integra_Delhi.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# HR0620000141_Sharp Business_Mundka.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# HR0620000140_Integra_Mumbai.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000534.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000533.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000533 (1).pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000526.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# MH2720000524.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# HR0620000126_Integra_Delhi.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# HR0620000139_Integra_Mumbai.pdf
# Item
# No <class 'str'>
# Product Code & Description Uom <class 'str'>
# Quantity <class 'str'>
# Unit Price <class 'str'>
# Amount <class 'str'>
# PFU 1828-2.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Installation DVD's for SV600 5,000
# HSN: 8473 30 99
# VALUE IN INR : 10,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1833.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Fujitsu Scanners IX1400-PPM 30,000
# Sr. no. CAFHY90039
# HSN: 8471 60 50
# VALUE IN INR : 30,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1831.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Fujitsu Scanners SP1130N-PPM 30,000
# Sr. no. C9VJY90030
# HSN: 8471 60 50
# VALUE IN INR : 30,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1828-3.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Installation DVD's for SV600 5,000
# HSN: 8473 30 99
# VALUE IN INR : 10,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1828-1.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Installation DVD's for SV600 5,000
# HSN: 8473 30 99
# VALUE IN INR : 10,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1830.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Fujitsu Scanners SP1130N-PPM 30,000
# Sr. no. C9VJY90005
# HSN: 8471 60 50
# VALUE IN INR : 30,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1829.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Fujitsu Scanners SP1130N-PPM 30,000
# Sr. no. C9VJY90046
# HSN: 8471 60 50
# VALUE IN INR : 30,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1828-16.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Installation DVD's for SV600 5,000
# HSN: 8473 30 99
# VALUE IN INR : 10,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1828-12.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Installation DVD's for SV600 5,000
# HSN: 8473 30 99
# VALUE IN INR : 10,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1828-13.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Installation DVD's for SV600 5,000
# HSN: 8473 30 99
# VALUE IN INR : 10,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1828-11.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Installation DVD's for SV600 5,000
# HSN: 8473 30 99
# VALUE IN INR : 10,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1828-10.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Installation DVD's for SV600 5,000
# HSN: 8473 30 99
# VALUE IN INR : 10,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
# PFU 1828-15.pdf
# Sl.No. <class 'str'>
# Part Number/
# Serial Number <class 'str'>
# Item Description Unit
# Price <class 'str'>
# ????????? Installation DVD's for SV600 5,000
# HSN: 8473 30 99
# VALUE IN INR : 10,000.00
# None <class 'NoneType'>
# None <class 'NoneType'>
# Quantity <class 'str'>
